# %% [markdown]
# This version uses Milvus through Docker Compose so you must have Docker installed to run this notebook (Milvus is spun up via `docker compose up -d` as shown in the block below)

# %%
# ! pip install -qU pymilvus langchain sentence-transformers tiktoken octoai-sdk openai 
# ! zsh ../standalone_embed.sh start

# %%
from dotenv import load_dotenv
import os

load_dotenv()
os.environ["OPENAI_API_KEY"] = os.getenv("OPENAI_API_KEY")

# %%
from langchain_openai import OpenAI
llm = OpenAI()

# %%
from langchain_community.embeddings import HuggingFaceEmbeddings
from langchain_community.vectorstores import Milvus

# %%
embeddings = HuggingFaceEmbeddings(model_name="TownsWu/PEG")
# Out:
# No sentence-transformers model found with name TownsWu/PEG. Creating a new one with MEAN pooling.
# /Users/yujiantang/Documents/workspace/rag_cookbooks/rcbs/lib/python3.12/site-packages/huggingface_hub/file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(

# %%
from langchain.text_splitter import CharacterTextSplitter
from langchain.schema import Document
import os

# %%
files = os.listdir("./chinese_city_data")

# %%
files
# Out:
# ['开罗.txt',
#  '多伦多.txt',
#  '莫斯科.txt',
#  '芝加哥.txt',
#  '柏林.txt',
#  '里斯本.txt',
#  '休斯敦.txt',
#  '亚特兰大.txt',
#  '卡拉奇.txt',
#  '上海市_(中華民國).txt',
#  '波士顿.txt',
#  '巴黎.txt',
#  '哥本哈根.txt',
#  '慕尼黑.txt',
#  '西雅圖.txt',
#  '东京.txt',
#  '北京市.txt',
#  '伦敦.txt',
#  '旧金山.txt']

# %%
file_texts = []

# %%
for file in files:
    with open(f"./chinese_city_data/{file}") as f:
        file_text = f.read()
    text_splitter = CharacterTextSplitter.from_tiktoken_encoder(
        chunk_size=512, chunk_overlap=64, 
    )
    texts = text_splitter.split_text(file_text)
    for i, chunked_text in enumerate(texts):
        file_texts.append(Document(page_content=chunked_text, 
                metadata={"doc_title": file.split(".")[0], "chunk_num": i}))
# Out:
# Created a chunk of size 1343, which is longer than the specified 512
# Created a chunk of size 614, which is longer than the specified 512
# Created a chunk of size 1809, which is longer than the specified 512
# Created a chunk of size 1798, which is longer than the specified 512
# Created a chunk of size 1239, which is longer than the specified 512
# Created a chunk of size 852, which is longer than the specified 512
# Created a chunk of size 1497, which is longer than the specified 512
# Created a chunk of size 584, which is longer than the specified 512
# Created a chunk of size 585, which is longer than the specified 512
# Created a chunk of size 567, which is longer than the specified 512
# Created a chunk of size 1481, which is longer than the specified 512
# Created a chunk of size 1752, which is longer than the specified 512
# Created a chunk of size 1745, which is longer than the specified 512
# Created a chunk of size 1046, which is longer than the specified 512
# Created a chunk of size 1077, which is longer than the specified 512
# Created a chunk of size 667, which is longer than the specified 512
# Created a chunk of size 863, which is longer than the specified 512
# Created a chunk of size 579, which is longer than the specified 512
# Created a chunk of size 812, which is longer than the specified 512
# Created a chunk of size 1170, which is longer than the specified 512
# Created a chunk of size 1212, which is longer than the specified 512
# Created a chunk of size 596, which is longer than the specified 512
# Created a chunk of size 781, which is longer than the specified 512
# Created a chunk of size 814, which is longer than the specified 512
# Created a chunk of size 1102, which is longer than the specified 512
# Created a chunk of size 523, which is longer than the specified 512
# Created a chunk of size 2049, which is longer than the specified 512
# Created a chunk of size 2282, which is longer than the specified 512
# Created a chunk of size 785, which is longer than the specified 512
# Created a chunk of size 726, which is longer than the specified 512
# Created a chunk of size 689, which is longer than the specified 512
# Created a chunk of size 1597, which is longer than the specified 512
# Created a chunk of size 2121, which is longer than the specified 512
# Created a chunk of size 1229, which is longer than the specified 512
# Created a chunk of size 608, which is longer than the specified 512
# Created a chunk of size 540, which is longer than the specified 512
# Created a chunk of size 1959, which is longer than the specified 512
# Created a chunk of size 1166, which is longer than the specified 512
# Created a chunk of size 720, which is longer than the specified 512
# Created a chunk of size 1172, which is longer than the specified 512
# Created a chunk of size 678, which is longer than the specified 512
# Created a chunk of size 980, which is longer than the specified 512
# Created a chunk of size 2310, which is longer than the specified 512
# Created a chunk of size 685, which is longer than the specified 512
# Created a chunk of size 1143, which is longer than the specified 512
# Created a chunk of size 689, which is longer than the specified 512
# Created a chunk of size 1678, which is longer than the specified 512
# Created a chunk of size 984, which is longer than the specified 512
# Created a chunk of size 1296, which is longer than the specified 512
# Created a chunk of size 1088, which is longer than the specified 512
# Created a chunk of size 877, which is longer than the specified 512
# Created a chunk of size 686, which is longer than the specified 512
# Created a chunk of size 663, which is longer than the specified 512
# Created a chunk of size 568, which is longer than the specified 512
# Created a chunk of size 1261, which is longer than the specified 512
# Created a chunk of size 2020, which is longer than the specified 512
# Created a chunk of size 2193, which is longer than the specified 512
# Created a chunk of size 1628, which is longer than the specified 512
# Created a chunk of size 2619, which is longer than the specified 512
# Created a chunk of size 944, which is longer than the specified 512
# Created a chunk of size 1528, which is longer than the specified 512
# Created a chunk of size 594, which is longer than the specified 512
# Created a chunk of size 751, which is longer than the specified 512
# Created a chunk of size 1521, which is longer than the specified 512
# Created a chunk of size 747, which is longer than the specified 512
# Created a chunk of size 1308, which is longer than the specified 512
# Created a chunk of size 517, which is longer than the specified 512
# Created a chunk of size 1110, which is longer than the specified 512
# Created a chunk of size 604, which is longer than the specified 512
# Created a chunk of size 524, which is longer than the specified 512
# Created a chunk of size 1168, which is longer than the specified 512
# Created a chunk of size 1329, which is longer than the specified 512
# Created a chunk of size 947, which is longer than the specified 512
# Created a chunk of size 839, which is longer than the specified 512
# Created a chunk of size 778, which is longer than the specified 512
# Created a chunk of size 1103, which is longer than the specified 512
# Created a chunk of size 628, which is longer than the specified 512
# Created a chunk of size 1139, which is longer than the specified 512
# Created a chunk of size 1427, which is longer than the specified 512
# Created a chunk of size 767, which is longer than the specified 512
# Created a chunk of size 945, which is longer than the specified 512
# Created a chunk of size 1549, which is longer than the specified 512
# Created a chunk of size 526, which is longer than the specified 512
# Created a chunk of size 1922, which is longer than the specified 512
# Created a chunk of size 864, which is longer than the specified 512
# Created a chunk of size 826, which is longer than the specified 512
# Created a chunk of size 579, which is longer than the specified 512
# Created a chunk of size 831, which is longer than the specified 512
# Created a chunk of size 732, which is longer than the specified 512
# Created a chunk of size 1120, which is longer than the specified 512
# Created a chunk of size 952, which is longer than the specified 512
# Created a chunk of size 633, which is longer than the specified 512
# Created a chunk of size 869, which is longer than the specified 512
# Created a chunk of size 930, which is longer than the specified 512
# Created a chunk of size 1508, which is longer than the specified 512
# Created a chunk of size 664, which is longer than the specified 512
# Created a chunk of size 601, which is longer than the specified 512
# Created a chunk of size 862, which is longer than the specified 512
# Created a chunk of size 1709, which is longer than the specified 512
# Created a chunk of size 1616, which is longer than the specified 512
# Created a chunk of size 601, which is longer than the specified 512
# Created a chunk of size 905, which is longer than the specified 512
# Created a chunk of size 2206, which is longer than the specified 512
# Created a chunk of size 756, which is longer than the specified 512
# Created a chunk of size 1769, which is longer than the specified 512
# Created a chunk of size 535, which is longer than the specified 512
# Created a chunk of size 833, which is longer than the specified 512
# Created a chunk of size 1421, which is longer than the specified 512
# Created a chunk of size 3858, which is longer than the specified 512
# Created a chunk of size 2337, which is longer than the specified 512
# Created a chunk of size 1720, which is longer than the specified 512
# Created a chunk of size 614, which is longer than the specified 512
# Created a chunk of size 823, which is longer than the specified 512
# Created a chunk of size 673, which is longer than the specified 512
# Created a chunk of size 1079, which is longer than the specified 512
# Created a chunk of size 956, which is longer than the specified 512
# Created a chunk of size 791, which is longer than the specified 512
# Created a chunk of size 1615, which is longer than the specified 512
# Created a chunk of size 2177, which is longer than the specified 512
# Created a chunk of size 996, which is longer than the specified 512
# Created a chunk of size 1439, which is longer than the specified 512
# Created a chunk of size 1553, which is longer than the specified 512
# Created a chunk of size 1096, which is longer than the specified 512
# Created a chunk of size 757, which is longer than the specified 512
# Created a chunk of size 1568, which is longer than the specified 512
# Created a chunk of size 623, which is longer than the specified 512
# Created a chunk of size 554, which is longer than the specified 512
# Created a chunk of size 1439, which is longer than the specified 512
# Created a chunk of size 1268, which is longer than the specified 512
# Created a chunk of size 1066, which is longer than the specified 512
# Created a chunk of size 1297, which is longer than the specified 512
# Created a chunk of size 1423, which is longer than the specified 512
# Created a chunk of size 1675, which is longer than the specified 512
# Created a chunk of size 544, which is longer than the specified 512
# Created a chunk of size 553, which is longer than the specified 512
# Created a chunk of size 1754, which is longer than the specified 512
# Created a chunk of size 1446, which is longer than the specified 512
# Created a chunk of size 858, which is longer than the specified 512
# Created a chunk of size 1293, which is longer than the specified 512
# Created a chunk of size 557, which is longer than the specified 512
# Created a chunk of size 1636, which is longer than the specified 512
# Created a chunk of size 1228, which is longer than the specified 512
# Created a chunk of size 1151, which is longer than the specified 512
# Created a chunk of size 878, which is longer than the specified 512
# Created a chunk of size 964, which is longer than the specified 512
# Created a chunk of size 2278, which is longer than the specified 512
# Created a chunk of size 863, which is longer than the specified 512
# Created a chunk of size 2385, which is longer than the specified 512
# Created a chunk of size 764, which is longer than the specified 512
# Created a chunk of size 861, which is longer than the specified 512
# Created a chunk of size 960, which is longer than the specified 512
# Created a chunk of size 1557, which is longer than the specified 512
# Created a chunk of size 1258, which is longer than the specified 512
# Created a chunk of size 1691, which is longer than the specified 512
# Created a chunk of size 788, which is longer than the specified 512
# Created a chunk of size 748, which is longer than the specified 512
# Created a chunk of size 840, which is longer than the specified 512
# Created a chunk of size 635, which is longer than the specified 512
# Created a chunk of size 526, which is longer than the specified 512
# Created a chunk of size 1425, which is longer than the specified 512
# Created a chunk of size 590, which is longer than the specified 512
# Created a chunk of size 725, which is longer than the specified 512
# Created a chunk of size 762, which is longer than the specified 512
# Created a chunk of size 571, which is longer than the specified 512
# Created a chunk of size 1674, which is longer than the specified 512
# Created a chunk of size 989, which is longer than the specified 512
# Created a chunk of size 802, which is longer than the specified 512
# Created a chunk of size 1011, which is longer than the specified 512
# Created a chunk of size 566, which is longer than the specified 512
# Created a chunk of size 1152, which is longer than the specified 512
# Created a chunk of size 1316, which is longer than the specified 512
# Created a chunk of size 800, which is longer than the specified 512
# Created a chunk of size 951, which is longer than the specified 512
# Created a chunk of size 959, which is longer than the specified 512
# Created a chunk of size 768, which is longer than the specified 512
# Created a chunk of size 703, which is longer than the specified 512
# Created a chunk of size 537, which is longer than the specified 512
# Created a chunk of size 802, which is longer than the specified 512
# Created a chunk of size 2020, which is longer than the specified 512
# Created a chunk of size 1535, which is longer than the specified 512
# Created a chunk of size 1092, which is longer than the specified 512
# Created a chunk of size 617, which is longer than the specified 512
# Created a chunk of size 557, which is longer than the specified 512
# Created a chunk of size 1681, which is longer than the specified 512
# Created a chunk of size 914, which is longer than the specified 512
# Created a chunk of size 1044, which is longer than the specified 512
# Created a chunk of size 1008, which is longer than the specified 512
# Created a chunk of size 1133, which is longer than the specified 512
# Created a chunk of size 2100, which is longer than the specified 512
# Created a chunk of size 1793, which is longer than the specified 512
# Created a chunk of size 587, which is longer than the specified 512
# Created a chunk of size 1194, which is longer than the specified 512
# Created a chunk of size 828, which is longer than the specified 512
# Created a chunk of size 1384, which is longer than the specified 512
# Created a chunk of size 579, which is longer than the specified 512
# Created a chunk of size 640, which is longer than the specified 512
# Created a chunk of size 660, which is longer than the specified 512
# Created a chunk of size 761, which is longer than the specified 512
# Created a chunk of size 2363, which is longer than the specified 512
# Created a chunk of size 954, which is longer than the specified 512
# Created a chunk of size 1427, which is longer than the specified 512
# Created a chunk of size 901, which is longer than the specified 512
# Created a chunk of size 520, which is longer than the specified 512
# Created a chunk of size 902, which is longer than the specified 512
# Created a chunk of size 667, which is longer than the specified 512
# Created a chunk of size 1100, which is longer than the specified 512
# Created a chunk of size 949, which is longer than the specified 512
# Created a chunk of size 1004, which is longer than the specified 512
# Created a chunk of size 594, which is longer than the specified 512
# Created a chunk of size 561, which is longer than the specified 512
# Created a chunk of size 946, which is longer than the specified 512
# Created a chunk of size 1413, which is longer than the specified 512
# Created a chunk of size 1381, which is longer than the specified 512
# Created a chunk of size 615, which is longer than the specified 512
# Created a chunk of size 792, which is longer than the specified 512
# Created a chunk of size 1766, which is longer than the specified 512
# Created a chunk of size 669, which is longer than the specified 512
# Created a chunk of size 1028, which is longer than the specified 512
# Created a chunk of size 1644, which is longer than the specified 512
# Created a chunk of size 747, which is longer than the specified 512
# Created a chunk of size 1106, which is longer than the specified 512
# Created a chunk of size 855, which is longer than the specified 512
# Created a chunk of size 952, which is longer than the specified 512
# Created a chunk of size 2111, which is longer than the specified 512
# Created a chunk of size 874, which is longer than the specified 512
# Created a chunk of size 1689, which is longer than the specified 512
# Created a chunk of size 952, which is longer than the specified 512
# Created a chunk of size 1146, which is longer than the specified 512
# Created a chunk of size 752, which is longer than the specified 512
# Created a chunk of size 638, which is longer than the specified 512
# Created a chunk of size 578, which is longer than the specified 512
# Created a chunk of size 846, which is longer than the specified 512
# Created a chunk of size 862, which is longer than the specified 512
# Created a chunk of size 655, which is longer than the specified 512
# Created a chunk of size 1472, which is longer than the specified 512
# Created a chunk of size 524, which is longer than the specified 512
# Created a chunk of size 571, which is longer than the specified 512
# Created a chunk of size 1481, which is longer than the specified 512
# Created a chunk of size 1193, which is longer than the specified 512
# Created a chunk of size 736, which is longer than the specified 512
# Created a chunk of size 677, which is longer than the specified 512
# Created a chunk of size 610, which is longer than the specified 512
# Created a chunk of size 844, which is longer than the specified 512
# Created a chunk of size 952, which is longer than the specified 512
# Created a chunk of size 1318, which is longer than the specified 512
# Created a chunk of size 1284, which is longer than the specified 512
# Created a chunk of size 753, which is longer than the specified 512
# Created a chunk of size 702, which is longer than the specified 512
# Created a chunk of size 734, which is longer than the specified 512
# Created a chunk of size 1022, which is longer than the specified 512
# Created a chunk of size 2255, which is longer than the specified 512
# Created a chunk of size 1481, which is longer than the specified 512
# Created a chunk of size 1171, which is longer than the specified 512
# Created a chunk of size 999, which is longer than the specified 512
# Created a chunk of size 1226, which is longer than the specified 512
# Created a chunk of size 1728, which is longer than the specified 512
# Created a chunk of size 815, which is longer than the specified 512
# Created a chunk of size 2755, which is longer than the specified 512
# Created a chunk of size 581, which is longer than the specified 512
# Created a chunk of size 893, which is longer than the specified 512
# Created a chunk of size 758, which is longer than the specified 512
# Created a chunk of size 3388, which is longer than the specified 512
# Created a chunk of size 627, which is longer than the specified 512
# Created a chunk of size 581, which is longer than the specified 512
# Created a chunk of size 3191, which is longer than the specified 512
# Created a chunk of size 741, which is longer than the specified 512
# Created a chunk of size 739, which is longer than the specified 512
# Created a chunk of size 593, which is longer than the specified 512
# Created a chunk of size 531, which is longer than the specified 512
# Created a chunk of size 2038, which is longer than the specified 512
# Created a chunk of size 1555, which is longer than the specified 512
# Created a chunk of size 1174, which is longer than the specified 512
# Created a chunk of size 900, which is longer than the specified 512
# Created a chunk of size 1650, which is longer than the specified 512
# Created a chunk of size 546, which is longer than the specified 512
# Created a chunk of size 576, which is longer than the specified 512
# Created a chunk of size 2654, which is longer than the specified 512
# Created a chunk of size 1125, which is longer than the specified 512
# Created a chunk of size 588, which is longer than the specified 512
# Created a chunk of size 624, which is longer than the specified 512
# Created a chunk of size 1810, which is longer than the specified 512
# Created a chunk of size 1714, which is longer than the specified 512
# Created a chunk of size 556, which is longer than the specified 512
# Created a chunk of size 843, which is longer than the specified 512
# Created a chunk of size 1952, which is longer than the specified 512
# Created a chunk of size 971, which is longer than the specified 512
# Created a chunk of size 543, which is longer than the specified 512
# Created a chunk of size 849, which is longer than the specified 512
# Created a chunk of size 536, which is longer than the specified 512
# Created a chunk of size 1815, which is longer than the specified 512
# Created a chunk of size 943, which is longer than the specified 512
# Created a chunk of size 559, which is longer than the specified 512
# Created a chunk of size 1296, which is longer than the specified 512
# Created a chunk of size 763, which is longer than the specified 512
# Created a chunk of size 1520, which is longer than the specified 512
# Created a chunk of size 1852, which is longer than the specified 512
# Created a chunk of size 1386, which is longer than the specified 512
# Created a chunk of size 790, which is longer than the specified 512
# Created a chunk of size 542, which is longer than the specified 512
# Created a chunk of size 960, which is longer than the specified 512
# Created a chunk of size 540, which is longer than the specified 512
# Created a chunk of size 839, which is longer than the specified 512
# Created a chunk of size 580, which is longer than the specified 512
# Created a chunk of size 1179, which is longer than the specified 512
# Created a chunk of size 1952, which is longer than the specified 512
# Created a chunk of size 862, which is longer than the specified 512
# Created a chunk of size 1194, which is longer than the specified 512
# Created a chunk of size 725, which is longer than the specified 512
# Created a chunk of size 998, which is longer than the specified 512
# Created a chunk of size 741, which is longer than the specified 512
# Created a chunk of size 1040, which is longer than the specified 512
# Created a chunk of size 517, which is longer than the specified 512
# Created a chunk of size 816, which is longer than the specified 512
# Created a chunk of size 626, which is longer than the specified 512
# Created a chunk of size 816, which is longer than the specified 512
# Created a chunk of size 570, which is longer than the specified 512
# Created a chunk of size 1114, which is longer than the specified 512
# Created a chunk of size 1280, which is longer than the specified 512
# Created a chunk of size 950, which is longer than the specified 512
# Created a chunk of size 877, which is longer than the specified 512
# Created a chunk of size 640, which is longer than the specified 512
# Created a chunk of size 1645, which is longer than the specified 512
# Created a chunk of size 753, which is longer than the specified 512
# Created a chunk of size 556, which is longer than the specified 512
# Created a chunk of size 1116, which is longer than the specified 512
# Created a chunk of size 1195, which is longer than the specified 512
# Created a chunk of size 1964, which is longer than the specified 512
# Created a chunk of size 861, which is longer than the specified 512
# Created a chunk of size 741, which is longer than the specified 512
# Created a chunk of size 1228, which is longer than the specified 512
# Created a chunk of size 1156, which is longer than the specified 512
# Created a chunk of size 1103, which is longer than the specified 512
# Created a chunk of size 952, which is longer than the specified 512
# Created a chunk of size 1574, which is longer than the specified 512
# Created a chunk of size 733, which is longer than the specified 512
# Created a chunk of size 1490, which is longer than the specified 512
# Created a chunk of size 1103, which is longer than the specified 512
# Created a chunk of size 1941, which is longer than the specified 512
# Created a chunk of size 1774, which is longer than the specified 512
# Created a chunk of size 1361, which is longer than the specified 512
# Created a chunk of size 1307, which is longer than the specified 512
# Created a chunk of size 782, which is longer than the specified 512
# Created a chunk of size 607, which is longer than the specified 512
# Created a chunk of size 886, which is longer than the specified 512

# %%
# For the first run
# 
vector_store = Milvus.from_documents(
    file_texts,
    embedding=embeddings,
    connection_args={"host": "localhost", "port": 19530},
    collection_name="chinese_cities"
)

# if you already have the data you need stored in Milvus
# vector_store = Milvus(
#     embedding_function=embeddings,
#     connection_args={"host": "localhost", "port": 19530},
#     collection_name="chinese_cities"
# )

# %%
retriever = vector_store.as_retriever()

# %%
from langchain.prompts import ChatPromptTemplate
template="""You are an assistant for question-answering tasks. 
Use the following pieces of retrieved context to answer the question. 
If you don't know the answer, just say that you don't know. 
Use three sentences maximum and keep the answer concise.
Answer in Chinese.
Question: {question} 
Context: {context} 
Answer:"""
prompt = ChatPromptTemplate.from_template(template)

# %%
from langchain_core.runnables import RunnablePassthrough
from langchain_core.output_parsers import StrOutputParser
chain = (
    {"context": retriever, "question": RunnablePassthrough()}
    | prompt
    | llm
    | StrOutputParser()
)

# %%
response = chain.invoke("东京 应该参观哪些地标？")

# %%
response
# Out:
# ' 东京塔，皇居，浅草寺'

# %%
response_2 = chain.invoke("What landmarks should I visit in Tokyo?")

# %%
response_2
# Out:
# ' 你应该去东京的富士箱根伊豆国立公园和东京晴空塔。'
